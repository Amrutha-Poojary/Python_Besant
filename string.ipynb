# %%
# sequence of character
# advance datatype
# immutable
#

# %%
print('hello')
print("hello") 
print('''hello''')
print("""hello""")
# Out:
# hello
# hello
# hello
# hello

# %%
name =" "
print(name)
print(type(name))
# Out:
#
# <class 'str'>

# %%
first_name = "nilesh"
last_name = "shetty"
full_name = first_name + last_name
print(full_name)
# Out:
# nileshshetty

# %%
first_name[0]
# Out:
# 'n'

# %%
full_name[::-1]
# Out:
# 'yttehshselin'

# %%
"nilesh" == "Nilesh"
# Out:
# False

# %%
indian_names = [
    "Amit",
    "Ganesh",
    "dhanush",
    "Anjali",
    "Suresh",
    "Ravi",
    "Neha",
    "naresh",
    "Vikram",
    "Pooja"
]

# %%
for char in"vikram":
    print(char)
# Out:
# v
# i
# k
# r
# a
# m

# %%
# print 1st 2 character in all names
# print all the name contains "e" letter
# print all the ends with "sh"
#  print name atleast length should be 5 character



for name in indian_names:
    print(name)
# Out:
# Amit
# Ganesh
# dhanush
# Anjali
# Suresh
# Ravi
# Neha
# naresh
# Vikram
# Pooja

# %%
for name in indian_names:
    print(name[0:2])
# Out:
# Am
# Ga
# dh
# An
# Su
# Ra
# Ne
# na
# Vi
# Po

# %%
for name in indian_names:
    if "e" in name:
        print(name)
# Out:
# Ganesh
# Suresh
# Neha
# naresh

# %%
for name in indian_names:
    if name.endswith("sh"):
        print(name)
# Out:
# Ganesh
# dhanush
# Suresh
# naresh

# %%
len("Ganesh")
# Out:
# 6

# %%
for name in indian_names:
    print(name.lower())
# Out:
# amit
# ganesh
# dhanush
# anjali
# suresh
# ravi
# neha
# naresh
# vikram
# pooja

# %%
for name in indian_names:
    print(name.upper())
# Out:
# AMIT
# GANESH
# DHANUSH
# ANJALI
# SURESH
# RAVI
# NEHA
# NARESH
# VIKRAM
# POOJA

# %%
for name in indian_names:
    print(name.capitalize())
# Out:
# Amit
# Ganesh
# Dhanush
# Anjali
# Suresh
# Ravi
# Neha
# Naresh
# Vikram
# Pooja
