# %%
# sequence of character
# advance datatype
# immutable
#

# %%
print('hello')
print("hello") 
print('''hello''')
print("""hello""")
# Out:
# hello
# hello
# hello
# hello

# %%
name =" "
print(name)
print(type(name))
# Out:
#
# <class 'str'>

# %%
first_name = "nilesh"
last_name = "shetty"
full_name = first_name + last_name
print(full_name)
# Out:
# nileshshetty

# %%
first_name[0]
# Out:
# 'n'

# %%
full_name[::-1]
# Out:
# 'yttehshselin'

# %%
"nilesh" == "Nilesh"
# Out:
# False
