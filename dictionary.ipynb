# %%
fruits = {"apple" :200, "kiwi": 200, "orange":500, "apple":800}
fruits
# Out:
# {'apple': 800, 'kiwi': 200, 'orange': 500}

# %%
fruits.pop("apple")
# Out:
# 800

# %%
fruits
# Out:
# {'kiwi': 200, 'orange': 500}

# %%
word = "apple"
char_count = {}
for char in word:
    if char in char_count:
        char_count[char]+=1
    else:
        char_count[char]=1
char_count
# Out:
# {'a': 1, 'p': 2, 'l': 1, 'e': 1}

# %%
word = "apple"
char_count = {}
for char in word:
    if char in char_count:
        char_count[char]+=1
    else:
        char_count[char]=1
    print(char_count)
# Out:
# {'a': 1}
# {'a': 1, 'p': 1}
# {'a': 1, 'p': 2}
# {'a': 1, 'p': 2, 'l': 1}
# {'a': 1, 'p': 2, 'l': 1, 'e': 1}
